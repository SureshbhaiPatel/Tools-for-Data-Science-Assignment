# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# # Data Science Tools and Ecosystem
#
# Welcome to this notebook on **Data Science Tools and Ecosystem**, where we will explore the main components that make up the field of Data Science. This includes programming languages, libraries, tools, and some useful examples in Python.

# %% [markdown]
# In this notebook, **Data Science Tools and Ecosystem** are summarized.
#
# The goal is to provide an overview of the most commonly used technologies and practices in the field of Data Science, including programming languages, libraries, and development environments. You will also learn how to perform simple mathematical operations in Python.

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1. **Python** – Widely used for data cleaning, analysis, and machine learning.
# 2. **R** – Excellent for statistical computing and visualization.
# 3. **SQL** – Used to query and manage data stored in databases.
# 4. **Julia** – Known for high-performance numerical analysis.
# 5. **Scala** – Used with Apache Spark for large-scale data processing.
# 6. **Java** – Often used in enterprise-level data systems.

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1. **Pandas** – For data manipulation and analysis.
# 2. **NumPy** – For numerical computations and working with arrays.
# 3. **Matplotlib** – For data visualization in Python.
# 4. **Scikit-learn** – For machine learning algorithms and modeling.
# 5. **TensorFlow** – For deep learning and neural networks.
# 6. **Keras** – High-level neural network API built on top of TensorFlow.
# 7. **Seaborn** – For statistical data visualization.

# %% [markdown]
# | Data Science Tools        |
# |----------------------------|
# | Jupyter Notebook           |
# | RStudio                    |
# | Google Colab               |
# | Apache Zeppelin            |
# | Visual Studio Code         |
# | Spyder IDE                 |

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python.
#
# Arithmetic expressions are used to perform mathematical operations such as addition, subtraction, multiplication, and division. These expressions help in building more complex calculations, such as statistical models or data transformations.

# %%
# This is a simple arithmetic expression to multiply then add integers
(3 * 4) + 5
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# **Objectives:**
#
# In this notebook, you will learn how to:
#
# - List popular programming languages used in Data Science
# - Identify commonly used Data Science libraries and frameworks
# - Create and format tables using Markdown
# - Demonstrate basic arithmetic operations in Python
# - Convert time measurements using Python
# - Understand the ecosystem and tools that support the Data Science workflow

# %% [markdown]
# ## Author
# **Sureshbhai Patel**
#
# Data Enthusiast | Lifelong Learner | Data Scientist
