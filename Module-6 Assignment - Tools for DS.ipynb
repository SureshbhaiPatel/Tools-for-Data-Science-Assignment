# %% [markdown]
# My Assignment

# %% [markdown]
# ## Introduction
# This is an Assignment of Tools for Data Science Course

# %% [markdown]
# ## Data Science Languages
# Some of the commonly used programming languages in Data Science are:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Some of the popular libraries used by data scientists include:
# - Pandas
# - NumPy
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - ggplot2 (for R)

# %% [markdown]
# ## Data Science Tools
#
# | Category          | Tool Name        |
# |------------------|------------------|
# | IDE              | Jupyter Notebook |
# | IDE              | RStudio          |
# | Visualization    | Tableau          |
# | Big Data Tool    | Apache Spark     |
# | Version Control  | GitHub           |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# The following cells will demonstrate basic arithmetic operations such as addition and multiplication.

# %%
# Multiply and add numbers

(5 * 4) + 3

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# In this notebook, we will:
# - Identify data science languages
# - Explore libraries used in data science
# - List key tools for data science
# - Practice basic arithmetic operations in Python
# - Convert time units using code

# %% [markdown]
# ## Author
# Sureshbhai Patel
